# %%
# set matpltolob to draw plots inline
# %matplotlib inline

# import matplotlib pyplot
import matplotlib.pyplot as plt

# import numpy
import numpy as np 

# import pandas
import pandas as pd

# %% [markdown]
# ####################################################

# %%
# Online Retail Data Set
# *from https://archive.ics.uci.edu/ml/datasets/online+retail

# import dataset (excel file)
data = pd.read_excel("online-retail.xlsx")

# %%
# Explore Data
data.head()
# Out:
#    InvoiceNo StockCode                         Description  Quantity  \
# 0     577130     22827  RUSTIC  SEVENTEEN DRAWER SIDEBOARD         1
# 1     574705     22827  RUSTIC  SEVENTEEN DRAWER SIDEBOARD         1
# 2     567616     22827  RUSTIC  SEVENTEEN DRAWER SIDEBOARD         1
# 3     567139     22828        REGENCY MIRROR WITH SHUTTERS         1
# 4     566184     22827  RUSTIC  SEVENTEEN DRAWER SIDEBOARD         1
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2011-11-17 19:58:00      165.0     15861.0  United Kingdom
# 1 2011-11-06 14:06:00      165.0     14553.0  United Kingdom
# 2 2011-09-21 12:23:00      165.0     14911.0            EIRE
# 3 2011-09-16 14:45:00      165.0     13563.0  United Kingdom
# 4 2011-09-09 13:01:00      165.0     16723.0  United Kingdom

# %%
# A simple line plot

plt.plot([1,2,3,4,5,6])
plt.show();

# %%
# A line plot on our sales data

plt.figure(figsize=(10,6))
plt.plot(data['InvoiceDate'], data['Quantity'])
plt.xlabel('Invoice Date')
plt.ylabel('Quantity')
plt.show()

# %%
data.loc[data['StockCode'] == 22827]
# Out:
#      InvoiceNo StockCode                         Description  Quantity  \
# 0       577130     22827  RUSTIC  SEVENTEEN DRAWER SIDEBOARD         1
# 1       574705     22827  RUSTIC  SEVENTEEN DRAWER SIDEBOARD         1
# 2       567616     22827  RUSTIC  SEVENTEEN DRAWER SIDEBOARD         1
# 4       566184     22827  RUSTIC  SEVENTEEN DRAWER SIDEBOARD         1
# 5       564357     22827  RUSTIC  SEVENTEEN DRAWER SIDEBOARD         1
# 6       558627     22827  RUSTIC  SEVENTEEN DRAWER SIDEBOARD         1
# 7       554348     22827  RUSTIC  SEVENTEEN DRAWER SIDEBOARD         1
# 9       548490     22827  RUSTIC  SEVENTEEN DRAWER SIDEBOARD         1
# 11      545345     22827  RUSTIC  SEVENTEEN DRAWER SIDEBOARD         1
# 12      545305     22827  RUSTIC  SEVENTEEN DRAWER SIDEBOARD         1
# 13      544911     22827  RUSTIC  SEVENTEEN DRAWER SIDEBOARD         1
# 14      544824     22827  RUSTIC  SEVENTEEN DRAWER SIDEBOARD         1
# ...

# %%
data1 = data.loc[data['StockCode'] == 22827].sort_values("InvoiceDate")

# %%
plt.figure(figsize=(10,6))
plt.plot(data1['InvoiceDate'], data1['Quantity'])
plt.xlabel('Invoice Date')
plt.ylabel('Quantity')
plt.show()

# %%
data2 = data.loc[data['StockCode'] == 22828].sort_values("InvoiceDate")

plt.figure(figsize=(10,6))
plt.plot(data2['InvoiceDate'], data2['Quantity'])
plt.xlabel('Invoice Date')
plt.ylabel('Quantity')
plt.show()
