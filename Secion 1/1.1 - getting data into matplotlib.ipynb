# %%
# set matpltolob to draw plots inline
# %matplotlib inline

# import matplotlib pyplot
import matplotlib.pyplot as plt

# import numpy
import numpy as np 

# import pandas
import pandas as pd

# %% [markdown]
# ####################################################

# %%
# Passing ist data to plot
x = [0, 1, 2, 3, 4, 5]
y = [0, 10, 20, 30, 40, 50]

plt.plot(x, y)
plt.show()

# %% [markdown]
# ################################################

# %%
# using numpy to process data and then pass it to matplotlib for plotting

x = np.arange(0,100) 
y = 9 * x + 7 

plt.plot(x,y) 
plt.show()

# %% [markdown]
# ########################################################

# %%
# plotting data from files read using pandas

# Gross World Product Data since 1970 - colelcted from wikipedia
data = pd.read_csv("gwp.csv")

# %%
# Explore Data
data
# Out:
#    Year       GWP
# 0  2014  77868.00
# 1  2010  62220.00
# 2  2005  43070.00
# 3  2000  41016.69
# 4  1995  33644.33
# 5  1990  27539.57
# 6  1985  22481.11
# 7  1980  18818.44
# 8  1975  15149.42
# 9  1970  12137.94

# %%
# Plotting pandas dataframe by passing dataframes columns as x and y axis

plt.plot(data['Year'], data['GWP'])
plt.show()

# %%
# Data Visualization by calling plot function directly on the dataframe

# Set Year as index
data1 = data.set_index("Year")

# %%
# Display new dataframe
data1
# Out:
#            GWP
# Year
# 2014  77868.00
# 2010  62220.00
# 2005  43070.00
# 2000  41016.69
# 1995  33644.33
# 1990  27539.57
# 1985  22481.11
# 1980  18818.44
# 1975  15149.42
# 1970  12137.94

# %%
# Creating a plot by calling plot directly on the dataframe

data1['GWP'].plot()
plt.show()
